# %%
import numpy as np
import matplotlib as mtb
import pandas as pd
import plotly as plt
import seaborn as sns
df = pd.read_csv("Electric_Vehicle_Population_Data.csv")

# %%
df.head(20)
# Out:
#     VIN (1-10)     County          City State  Postal Code  Model Year  \
# 0   5UXKT0C59G     Yakima        Zillah    WA      98953.0        2016
# 1   5YJ3E1EA2J  Snohomish       Edmonds    WA      98020.0        2018
# 2   1G1RE6E4XE     Kitsap  Port Orchard    WA      98367.0        2014
# 3   2C4RC1L76M     Skagit           Bow    WA      98232.0        2021
# 4   5YJ3E1EA2J   Thurston       Olympia    WA      98513.0        2018
# 5   WA1E2BFY8N  Snohomish     Snohomish    WA      98296.0        2022
# 6   KNDCE3LG2K   Thurston       Olympia    WA      98506.0        2019
# 7   5YJ3E1EB9K  Snohomish       Edmonds    WA      98020.0        2019
# 8   WBY8P2C57K       King       Seattle    WA      98102.0        2019
# 9   1FADP5CU2D   Thurston         Lacey    WA      98503.0        2013
# 10  5YJ3E1EB4J  Snohomish       Bothell    WA      98021.0        2018
# 11  1N4BZ0CP5H       King     Fall City    WA      98024.0        2017
# ...

# %%
df.shape
# 1,73,533 rows and 17 columns
# Out:
# (173533, 17)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=173533, step=1)

# %%
df.columns
# Out:
# Index(['VIN (1-10)', 'County', 'City', 'State', 'Postal Code', 'Model Year',
#        'Make', 'Model', 'Electric Vehicle Type',
#        'Clean Alternative Fuel Vehicle (CAFV) Eligibility', 'Electric Range',
#        'Base MSRP', 'Legislative District', 'DOL Vehicle ID',
#        'Vehicle Location', 'Electric Utility', '2020 Census Tract'],
#       dtype='object')

# %%
df.dtypes
# Out:
# VIN (1-10)                                            object
# County                                                object
# City                                                  object
# State                                                 object
# Postal Code                                          float64
# Model Year                                             int64
# Make                                                  object
# Model                                                 object
# Electric Vehicle Type                                 object
# Clean Alternative Fuel Vehicle (CAFV) Eligibility     object
# Electric Range                                       float64
# Base MSRP                                            float64
# Legislative District                                 float64
# DOL Vehicle ID                                         int64
# Vehicle Location                                      object
# ...

# %%
df['County'].unique()
# Out:
# array(['Yakima', 'Snohomish', 'Kitsap', 'Skagit', 'Thurston', 'King',
#        'Chelan', 'Stevens', 'Spokane', 'Grant', 'Douglas', 'Island',
#        'Lincoln', nan, 'Columbia', 'Pierce', 'San Juan', 'Clark',
#        'Whatcom', 'Cowlitz', 'Jefferson', 'Klickitat', 'Grays Harbor',
#        'Franklin', 'Mason', 'Lewis', 'Benton', 'Whitman', 'Walla Walla',
#        'Skamania', 'Clallam', 'Cook', 'Kittitas', 'Santa Clara',
#        'Montgomery', 'Pacific', 'Okanogan', 'Asotin', 'Wahkiakum',
#        'Pend Oreille', 'Collin', 'Yuba', 'San Diego', 'Fairfax',
#        'Saratoga', 'Honolulu', 'Ferry', 'Adams', 'Garfield', 'Calvert',
#        'Suffolk', 'Cumberland', 'Leavenworth', 'Maricopa', 'Beaufort',
#        'Multnomah', 'Alexandria', 'Berkeley', 'Loudoun', 'Orange',
#        'Harford', 'Anne Arundel', 'Rockdale', 'Virginia Beach', 'Tarrant',
#        'Harris', 'Harnett', "St. Mary's", 'Boulder', 'Placer',
#        'Chesapeake', 'Ventura', 'Monterey', 'Autauga', 'Middlesex',
# ...

# %%
df.nunique()
# Out:
# VIN (1-10)                                            10571
# County                                                  193
# City                                                    710
# State                                                    46
# Postal Code                                             847
# Model Year                                               22
# Make                                                     40
# Model                                                   139
# Electric Vehicle Type                                     2
# Clean Alternative Fuel Vehicle (CAFV) Eligibility         3
# Electric Range                                          102
# Base MSRP                                                31
# Legislative District                                     49
# DOL Vehicle ID                                       173533
# Vehicle Location                                        846
# Electric Utility                                         76
# ...

# %%
df.count()
# Out:
# VIN (1-10)                                           173533
# County                                               173528
# City                                                 173528
# State                                                173533
# Postal Code                                          173528
# Model Year                                           173533
# Make                                                 173533
# Model                                                173533
# Electric Vehicle Type                                173533
# Clean Alternative Fuel Vehicle (CAFV) Eligibility    173533
# Electric Range                                       173532
# Base MSRP                                            173532
# Legislative District                                 173157
# DOL Vehicle ID                                       173533
# Vehicle Location                                     173523
# Electric Utility                                     173528
# ...

# %%
df['County'].value_counts()
# Out:
# King            90326
# Snohomish       20473
# Pierce          13509
# Clark           10161
# Thurston         6235
#                 ...
# Kootenai            1
# Lee                 1
# York                1
# Newport News        1
# Worcester           1
# Name: County, Length: 193, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173533 entries, 0 to 173532
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   VIN (1-10)                                         173533 non-null  object
#  1   County                                             173528 non-null  object
#  2   City                                               173528 non-null  object
#  3   State                                              173533 non-null  object
#  4   Postal Code                                        173528 non-null  float64
#  5   Model Year                                         173533 non-null  int64
#  6   Make                                               173533 non-null  object
#  7   Model                                              173533 non-null  object
# ...

# %%
df.head(5)
# Out:
#    VIN (1-10)     County          City State  Postal Code  Model Year  \
# 0  5UXKT0C59G     Yakima        Zillah    WA      98953.0        2016
# 1  5YJ3E1EA2J  Snohomish       Edmonds    WA      98020.0        2018
# 2  1G1RE6E4XE     Kitsap  Port Orchard    WA      98367.0        2014
# 3  2C4RC1L76M     Skagit           Bow    WA      98232.0        2021
# 4  5YJ3E1EA2J   Thurston       Olympia    WA      98513.0        2018
#
#         Make     Model                   Electric Vehicle Type  \
# 0        BMW        X5  Plug-in Hybrid Electric Vehicle (PHEV)
# 1      TESLA   MODEL 3          Battery Electric Vehicle (BEV)
# 2  CHEVROLET      VOLT  Plug-in Hybrid Electric Vehicle (PHEV)
# 3   CHRYSLER  PACIFICA  Plug-in Hybrid Electric Vehicle (PHEV)
# 4      TESLA   MODEL 3          Battery Electric Vehicle (BEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0             Not eligible due to low battery range            14.0
# ...

# %%
df.Make == 'TESLA'
# Out:
# 0         False
# 1          True
# 2         False
# 3         False
# 4          True
#           ...
# 173528     True
# 173529     True
# 173530    False
# 173531    False
# 173532     True
# Name: Make, Length: 173533, dtype: bool

# %%
df.groupby('Make').get_group('TESLA')
# Out:
#         VIN (1-10)     County       City State  Postal Code  Model Year  \
# 1       5YJ3E1EA2J  Snohomish    Edmonds    WA      98020.0        2018
# 4       5YJ3E1EA2J   Thurston    Olympia    WA      98513.0        2018
# 7       5YJ3E1EB9K  Snohomish    Edmonds    WA      98020.0        2019
# 10      5YJ3E1EB4J  Snohomish    Bothell    WA      98021.0        2018
# 13      5YJYGDEF1L  Snohomish    Bothell    WA      98012.0        2020
# ...            ...        ...        ...   ...          ...         ...
# 173525  7SAYGDEE3P       King     Duvall    WA      98019.0        2023
# 173526  5YJ3E1EA0P      Clark      Camas    WA      98607.0        2023
# 173528  5YJ3E1EA0P       King    Redmond    WA      98052.0        2023
# 173529  5YJXCBE22H  Snohomish  Snohomish    WA      98296.0        2017
# 173532  5YJSA1E5XM       King    Seattle    WA      98117.0        2021
#
#          Make    Model           Electric Vehicle Type  \
# ...

# %%
df.isnull().sum()
# Out:
# VIN (1-10)                                             0
# County                                                 5
# City                                                   5
# State                                                  0
# Postal Code                                            5
# Model Year                                             0
# Make                                                   0
# Model                                                  0
# Electric Vehicle Type                                  0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# Electric Range                                         1
# Base MSRP                                              1
# Legislative District                                 376
# DOL Vehicle ID                                         0
# Vehicle Location                                      10
# Electric Utility                                       5
# ...

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# VIN (1-10)                                           0
# County                                               0
# City                                                 0
# State                                                0
# Postal Code                                          0
# Model Year                                           0
# Make                                                 0
# Model                                                0
# Electric Vehicle Type                                0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility    0
# Electric Range                                       0
# Base MSRP                                            0
# Legislative District                                 0
# DOL Vehicle ID                                       0
# Vehicle Location                                     0
# Electric Utility                                     0
# 2020 Census Tract                                    0
# dtype: int64

# %%
df.shape
# Out:
# (173151, 17)

# %%
df['Electric Range'].mean()
# Out:
# 60.13530386772239

# %%
df['Make'].value_counts()
# Out:
# TESLA                   77624
# NISSAN                  13992
# CHEVROLET               13460
# FORD                     8893
# BMW                      7450
# KIA                      7240
# TOYOTA                   6026
# VOLKSWAGEN               4876
# JEEP                     4331
# HYUNDAI                  4244
# VOLVO                    4075
# RIVIAN                   3848
# AUDI                     3557
# CHRYSLER                 2944
# MERCEDES-BENZ            1516
# PORSCHE                  1130
# MITSUBISHI                966
# MINI                      890
# POLESTAR                  876
# HONDA                     826
# SUBARU                    806
# FIAT                      801
# MAZDA                     431
# DODGE                     381
# LEXUS                     348
# CADILLAC                  307
# SMART                     274
# LINCOLN                   259
# LUCID                     236
# JAGUAR                    227
# GENESIS                   173
# ...

# %%
df[df['Clean Alternative Fuel Vehicle (CAFV) Eligibility'] == 'Clean Alternative Fuel Vehicle Eligible']
# Out:
#         VIN (1-10)     County          City State  Postal Code  Model Year  \
# 1       5YJ3E1EA2J  Snohomish       Edmonds    WA      98020.0        2018
# 2       1G1RE6E4XE     Kitsap  Port Orchard    WA      98367.0        2014
# 3       2C4RC1L76M     Skagit           Bow    WA      98232.0        2021
# 4       5YJ3E1EA2J   Thurston       Olympia    WA      98513.0        2018
# 6       KNDCE3LG2K   Thurston       Olympia    WA      98506.0        2019
# ...            ...        ...           ...   ...          ...         ...
# 173516  JHMZC5F14J  Snohomish       Edmonds    WA      98026.0        2018
# 173519  5YJYGDEEXL       King     Sammamish    WA      98074.0        2020
# 173523  1N4AZ0CPXD       King        Renton    WA      98059.0        2013
# 173524  5YJ3E1EA7L      Clark     Vancouver    WA      98662.0        2020
# 173529  5YJXCBE22H  Snohomish     Snohomish    WA      98296.0        2017
#
# ...

# %%
df[df['Clean Alternative Fuel Vehicle (CAFV) Eligibility'].str.contains('Clean Alternative Fuel Vehicle Eligible')]
# Out:
#         VIN (1-10)     County          City State  Postal Code  Model Year  \
# 1       5YJ3E1EA2J  Snohomish       Edmonds    WA      98020.0        2018
# 2       1G1RE6E4XE     Kitsap  Port Orchard    WA      98367.0        2014
# 3       2C4RC1L76M     Skagit           Bow    WA      98232.0        2021
# 4       5YJ3E1EA2J   Thurston       Olympia    WA      98513.0        2018
# 6       KNDCE3LG2K   Thurston       Olympia    WA      98506.0        2019
# ...            ...        ...           ...   ...          ...         ...
# 173516  JHMZC5F14J  Snohomish       Edmonds    WA      98026.0        2018
# 173519  5YJYGDEEXL       King     Sammamish    WA      98074.0        2020
# 173523  1N4AZ0CPXD       King        Renton    WA      98059.0        2013
# 173524  5YJ3E1EA7L      Clark     Vancouver    WA      98662.0        2020
# 173529  5YJXCBE22H  Snohomish     Snohomish    WA      98296.0        2017
#
# ...

# %%
# Find number of counties which have tesla and are made after 2017

df[(df.County=='Snohomish') & (df['Make']=='TESLA') & (df['Model Year']>2017)]
# Out:
#         VIN (1-10)     County        City State  Postal Code  Model Year  \
# 1       5YJ3E1EA2J  Snohomish     Edmonds    WA      98020.0        2018
# 7       5YJ3E1EB9K  Snohomish     Edmonds    WA      98020.0        2019
# 10      5YJ3E1EB4J  Snohomish     Bothell    WA      98021.0        2018
# 13      5YJYGDEF1L  Snohomish     Bothell    WA      98012.0        2020
# 15      5YJ3E1EA0J  Snohomish     Edmonds    WA      98026.0        2018
# ...            ...        ...         ...   ...          ...         ...
# 173458  5YJ3E1EB7K  Snohomish  Mill Creek    WA      98012.0        2019
# 173465  5YJ3E1EB8K  Snohomish     Edmonds    WA      98026.0        2019
# 173473  5YJYGDEE2L  Snohomish   Snohomish    WA      98290.0        2020
# 173478  5YJ3E1EA8P  Snohomish    Lynnwood    WA      98087.0        2023
# 173520  5YJ3E1EA8P  Snohomish     Everett    WA      98203.0        2023
#
#          Make    Model           Electric Vehicle Type  \
# ...

# %% [markdown]
# **Linear Regression**

# %%
linear_df = df[['Model Year', 'Electric Range']]

# %%
linear_df.head(10)
# Out:
#    Model Year  Electric Range
# 0        2016            14.0
# 1        2018           215.0
# 2        2014            38.0
# 3        2021            32.0
# 4        2018           215.0
# 5        2022            23.0
# 6        2019           239.0
# 7        2019           220.0
# 8        2019           153.0
# 9        2013            19.0

# %%
X = linear_df['Model Year']
y= linear_df['Electric Range']

# %%
import matplotlib.pyplot as plt
plt.scatter(X,y)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.4, random_state =23)

# %%
X_train
# Out:
# 160533    2021
# 8248      2023
# 101820    2023
# 63658     2023
# 21833     2022
#           ...
# 9715      2023
# 76889     2018
# 9267      2021
# 128075    2023
# 107370    2023
# Name: Model Year, Length: 103890, dtype: int64

# %%
X_train = np.array(X_train).reshape(-1,1)
X_test = np.array(X_test).reshape(-1,1)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
c = lr.intercept_
c
# Out:
# 29367.83366880319

# %%
m = lr.coef_
m
# Out:
# array([-14.50566176])

# %%
y_pred = lr.predict(X_train)
y_pred
# Out:
# array([51.89125713, 22.87993362, 22.87993362, ..., 51.89125713,
#        22.87993362, 22.87993362])
